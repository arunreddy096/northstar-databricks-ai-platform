-- %%
CREATE CATALOG IF NOT EXISTS northstar
MANAGED LOCATION 'abfss://managed@arnalla.dfs.core.windows.net/';

-- These inherit northstar's managed location automatically:
CREATE SCHEMA IF NOT EXISTS northstar.bronze;
CREATE SCHEMA IF NOT EXISTS northstar.silver;
CREATE SCHEMA IF NOT EXISTS northstar.gold;

-- This becomes a MANAGED table in the managed container — no LOCATION needed:
CREATE TABLE northstar.bronze.test (id INT);


DESCRIBE EXTENDED northstar.bronze.test;
